# %%
import pandas as pd
from pathlib import Path 

#create path for both CSV data sets
census_data_path = r"Resources\clean_census_data.csv"
cw_data_path = r"Resources\CWData.csv"

# Store the paths and command to read
census_data = pd.read_csv(census_data_path)
cw_data = pd.read_csv(cw_data_path)

# %%
cw_data.head()
# Out:
#    Fiscal Year     County     Region      Type of Allegation  Allegation Count
# 0         2022  Armstrong  1-Lubbock  Neglectful Supervision                11
# 1         2022  Armstrong  1-Lubbock          Physical Abuse                 5
# 2         2022  Armstrong  1-Lubbock            Sexual Abuse                 1
# 3         2022     Bailey  1-Lubbock         Emotional Abuse                 1
# 4         2022     Bailey  1-Lubbock  Neglectful Supervision                50

# %%
census_data.rename(columns=census_data.iloc[0], inplace = True)
census_data.head()
# Out:
#      County    Total      Less than $10,000      $10,000 to $14,999  \
# 0    County    Total      Less than $10,000      $10,000 to $14,999
# 1  Angelina   34,276                   5.1%                    3.9%
# 2   Bastrop   37,278                   6.3%                    3.6%
# 3      Bell  143,361                   6.7%                    3.6%
# 4     Bexar  754,632                   5.3%                    4.4%
#
#        $15,000 to $24,999      $25,000 to $34,999      $35,000 to $49,999  \
# 0      $15,000 to $24,999      $25,000 to $34,999      $35,000 to $49,999
# 1                   10.5%                    9.5%                   15.6%
# 2                    6.1%                    5.3%                   12.6%
# 3                    6.9%                    8.5%                   14.1%
# 4                    7.9%                    8.0%                   11.9%
#
#        $50,000 to $74,999      $75,000 to $99,999      $100,000 to $149,999  \
# 0      $50,000 to $74,999      $75,000 to $99,999      $100,000 to $149,999
# 1                   18.0%                   11.3%                     12.9%
# 2                   19.1%                   11.8%                     21.5%
# 3                   20.2%                   13.7%                     14.7%
# 4                   18.6%                   13.7%                     14.9%
#
#        $150,000 to $199,999      $200,000 or more  Median income (dollars)  \
# 0      $150,000 to $199,999      $200,000 or more  Median income (dollars)
# 1                      8.4%                  4.7%                   58,180
# 2                      8.9%                  4.9%                   72,663
# 3                      5.5%                  6.1%                   62,137
# 4                      7.9%                  7.4%                   65,854
#
#    Mean income (dollars)      Household income in the past 12 months  \
# 0  Mean income (dollars)      Household income in the past 12 months
# 1                 79,881                                       39.7%
# 2                 87,467                                       41.1%
# 3                 85,250                                       35.1%
# 4                 89,010                                       33.2%
#
#        Family income in the past 12 months  \
# 0      Family income in the past 12 months
# 1                                      (X)
# 2                                      (X)
# 3                                      (X)
# 4                                      (X)
#
#        Nonfamily income in the past 12 months
# 0      Nonfamily income in the past 12 months
# 1                                         (X)
# 2                                         (X)
# 3                                         (X)
# 4                                         (X)

# %%
census_data.drop(census_data.index[0], inplace=True)
census_data.head()
# Out:
#      County    Total     Less than $10,000     $10,000 to $14,999  \
# 1  Angelina   34,276                  5.1%                   3.9%
# 2   Bastrop   37,278                  6.3%                   3.6%
# 3      Bell  143,361                  6.7%                   3.6%
# 4     Bexar  754,632                  5.3%                   4.4%
# 5     Bowie   35,469                  8.7%                   5.9%
#
#       $15,000 to $24,999     $25,000 to $34,999     $35,000 to $49,999  \
# 1                  10.5%                   9.5%                  15.6%
# 2                   6.1%                   5.3%                  12.6%
# 3                   6.9%                   8.5%                  14.1%
# 4                   7.9%                   8.0%                  11.9%
# 5                  10.3%                   9.9%                  15.3%
#
#       $50,000 to $74,999     $75,000 to $99,999     $100,000 to $149,999  \
# 1                  18.0%                  11.3%                    12.9%
# 2                  19.1%                  11.8%                    21.5%
# 3                  20.2%                  13.7%                    14.7%
# 4                  18.6%                  13.7%                    14.9%
# 5                  20.3%                   9.3%                     9.8%
#
#       $150,000 to $199,999     $200,000 or more Median income (dollars)  \
# 1                     8.4%                 4.7%                  58,180
# 2                     8.9%                 4.9%                  72,663
# 3                     5.5%                 6.1%                  62,137
# 4                     7.9%                 7.4%                  65,854
# 5                     4.6%                 5.8%                  49,771
#
#   Mean income (dollars)     Household income in the past 12 months  \
# 1                79,881                                      39.7%
# 2                87,467                                      41.1%
# 3                85,250                                      35.1%
# 4                89,010                                      33.2%
# 5                74,515                                      42.2%
#
#       Family income in the past 12 months  \
# 1                                     (X)
# 2                                     (X)
# 3                                     (X)
# 4                                     (X)
# 5                                     (X)
#
#       Nonfamily income in the past 12 months
# 1                                        (X)
# 2                                        (X)
# 3                                        (X)
# 4                                        (X)
# 5                                        (X)

# %%
# Merge both data sets into one   
happy_childhood_data = pd.merge(census_data, cw_data, how="left", on=["County","County"])
happy_childhood_data
# Out:
#         County   Total     Less than $10,000     $10,000 to $14,999  \
# 0     Angelina  34,276                  5.1%                   3.9%
# 1     Angelina  34,276                  5.1%                   3.9%
# 2     Angelina  34,276                  5.1%                   3.9%
# 3     Angelina  34,276                  5.1%                   3.9%
# 4     Angelina  34,276                  5.1%                   3.9%
# ...        ...     ...                   ...                    ...
# 4434      Wise  25,430                  3.0%                   2.4%
# 4435      Wise  25,430                  3.0%                   2.4%
# 4436      Wise  25,430                  3.0%                   2.4%
# 4437      Wise  25,430                  3.0%                   2.4%
# 4438      Wise  25,430                  3.0%                   2.4%
#
#          $15,000 to $24,999     $25,000 to $34,999     $35,000 to $49,999  \
# 0                     10.5%                   9.5%                  15.6%
# 1                     10.5%                   9.5%                  15.6%
# 2                     10.5%                   9.5%                  15.6%
# 3                     10.5%                   9.5%                  15.6%
# 4                     10.5%                   9.5%                  15.6%
# ...                     ...                    ...                    ...
# 4434                   5.2%                   7.3%                  11.9%
# 4435                   5.2%                   7.3%                  11.9%
# 4436                   5.2%                   7.3%                  11.9%
# 4437                   5.2%                   7.3%                  11.9%
# 4438                   5.2%                   7.3%                  11.9%
#
#          $50,000 to $74,999     $75,000 to $99,999     $100,000 to $149,999  \
# 0                     18.0%                  11.3%                    12.9%
# 1                     18.0%                  11.3%                    12.9%
# 2                     18.0%                  11.3%                    12.9%
# 3                     18.0%                  11.3%                    12.9%
# 4                     18.0%                  11.3%                    12.9%
# ...                     ...                    ...                      ...
# 4434                  15.0%                  14.4%                    19.6%
# 4435                  15.0%                  14.4%                    19.6%
# 4436                  15.0%                  14.4%                    19.6%
# 4437                  15.0%                  14.4%                    19.6%
# 4438                  15.0%                  14.4%                    19.6%
#
#       ...     $200,000 or more Median income (dollars) Mean income (dollars)  \
# 0     ...                 4.7%                  58,180                79,881
# 1     ...                 4.7%                  58,180                79,881
# 2     ...                 4.7%                  58,180                79,881
# 3     ...                 4.7%                  58,180                79,881
# 4     ...                 4.7%                  58,180                79,881
# ...   ...                  ...                     ...                   ...
# 4434  ...                11.6%                  80,305               106,665
# 4435  ...                11.6%                  80,305               106,665
# 4436  ...                11.6%                  80,305               106,665
# 4437  ...                11.6%                  80,305               106,665
# 4438  ...                11.6%                  80,305               106,665
#
#          Household income in the past 12 months  \
# 0                                         39.7%
# 1                                         39.7%
# 2                                         39.7%
# 3                                         39.7%
# 4                                         39.7%
# ...                                         ...
# 4434                                      41.7%
# 4435                                      41.7%
# 4436                                      41.7%
# 4437                                      41.7%
# 4438                                      41.7%
#
#          Family income in the past 12 months  \
# 0                                        (X)
# 1                                        (X)
# 2                                        (X)
# 3                                        (X)
# 4                                        (X)
# ...                                      ...
# 4434                                     (X)
# 4435                                     (X)
# 4436                                     (X)
# 4437                                     (X)
# 4438                                     (X)
#
#          Nonfamily income in the past 12 months Fiscal Year       Region  \
# 0                                           (X)      2022.0   5-Beaumont
# 1                                           (X)      2022.0   5-Beaumont
# 2                                           (X)      2022.0   5-Beaumont
# 3                                           (X)      2022.0   5-Beaumont
# 4                                           (X)      2022.0   5-Beaumont
# ...                                         ...         ...          ...
# 4434                                        (X)      2013.0  3-Arlington
# 4435                                        (X)      2013.0  3-Arlington
# 4436                                        (X)      2013.0  3-Arlington
# 4437                                        (X)      2013.0  3-Arlington
# 4438                                        (X)      2013.0  3-Arlington
#
#                              Type of Allegation Allegation Count
# 0                                   Abandonment              3.0
# 1                               Emotional Abuse             32.0
# 2                               Medical Neglect             63.0
# 3                        Neglectful Supervision            684.0
# 4                                Physical Abuse            226.0
# ...                                         ...              ...
# 4434                     Neglectful Supervision            409.0
# 4435                             Physical Abuse            173.0
# 4436                           Physical Neglect             93.0
# 4437  Refusal To Accept Parental Responsibility              4.0
# 4438                               Sexual Abuse            135.0
#
# [4439 rows x 21 columns]

# %%
happy_childhood_data = happy_childhood_data.dropna()

# %%
happy_childhood_data.count()
# Out:
# County                                        4435
# Total                                         4435
#     Less than $10,000                         4435
#     $10,000 to $14,999                        4435
#     $15,000 to $24,999                        4435
#     $25,000 to $34,999                        4435
#     $35,000 to $49,999                        4435
#     $50,000 to $74,999                        4435
#     $75,000 to $99,999                        4435
#     $100,000 to $149,999                      4435
#     $150,000 to $199,999                      4435
#     $200,000 or more                          4435
# Median income (dollars)                       4435
# Mean income (dollars)                         4435
#     Household income in the past 12 months    4435
#     Family income in the past 12 months       4435
#     Nonfamily income in the past 12 months    4435
# Fiscal Year                                   4435
# Region                                        4435
# Type of Allegation                            4435
# Allegation Count                              4435
# dtype: int64

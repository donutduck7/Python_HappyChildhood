# %%
import pandas as pd
from pathlib import Path 

data_path = r"Resources\full_clean_dataset.csv"
df = pd.read_csv(data_path)
df
# Out:
#     Unnamed: 0      County      Total     Less than $10,000  \
# 0            0    Angelina     34,276                  5.1%
# 1            1     Bastrop     37,278                  6.3%
# 2            2        Bell    143,361                  6.7%
# 3            3       Bexar    754,632                  5.3%
# 4            4       Bowie     35,469                  8.7%
# 5            5    Brazoria    133,871                  3.7%
# 6            6      Brazos     93,580                 11.0%
# 7            7     Cameron    137,982                  8.2%
# 8            8      Collin    414,601                  2.9%
# 9            9       Comal     70,544                  2.8%
# 10          10     Coryell     27,660                  3.1%
# 11          11      Dallas    992,995                  5.5%
# 12          12      Denton    361,770                  4.0%
# 13          13       Ector     63,738                  7.5%
# 14          14       Ellis     73,227                  3.4%
# ...

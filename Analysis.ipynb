# %%
# Import dependencies
import pandas as pd
from pathlib import Path 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Establish data path & read in CSV
data_path = r"Resources\full_clean_dataset.csv"
df = pd.read_csv(data_path) 
df = df.rename(columns={'Total':'Total Number of Households'})

#df = df.drop(columns="Unnamed: 0")
df = df.dropna()

# Create new df with vaues needed to answer question, "Does household income affect type of cases?"
income_type_df = df[['Region','County', 'Total Number of Households', 'Median income (dollars)', 'Abandonment', 'Emotional Abuse',
                     'Medical Neglect', 'Neglectful Supervision', 'Physical Abuse', 'Physical Neglect',
                     'Refusal To Accept Parental Responsibility', 'Sex Trafficking', 'Sexual Abuse']]
# Check work
income_type_df
# Out:
#            Region      County Total Number of Households  \
# 0      5-Beaumont    Angelina                     34,276
# 1        7-Austin     Bastrop                     37,278
# 2        7-Austin        Bell                    143,361
# 3   8-San Antonio       Bexar                    754,632
# 4         4-Tyler       Bowie                     35,469
# 5       6-Houston    Brazoria                    133,871
# 6        7-Austin      Brazos                     93,580
# 7     11-Edinburg     Cameron                    137,982
# 8     3-Arlington      Collin                    414,601
# 9   8-San Antonio       Comal                     70,544
# 10       7-Austin     Coryell                     27,660
# 11    3-Arlington      Dallas                    992,995
# 12    3-Arlington      Denton                    361,770
# 13      9-Midland       Ector                     63,738
# 14    3-Arlington       Ellis                     73,227
# 17      6-Houston   Galveston                    143,725
# 18    3-Arlington     Grayson                     54,309
# 19        4-Tyler       Gregg                     47,877
# 20  8-San Antonio   Guadalupe                     66,711
# 21      6-Houston      Harris                  1,779,980
# 22        4-Tyler    Harrison                     26,795
# 23       7-Austin        Hays                    101,449
# 24        4-Tyler   Henderson                     33,671
# 25    11-Edinburg     Hidalgo                    270,891
# 26    3-Arlington        Hood                     25,700
# 27    3-Arlington        Hunt                     38,072
# 28     5-Beaumont   Jefferson                     96,171
# 29    3-Arlington     Johnson                     66,686
# 30    3-Arlington     Kaufman                     50,855
# 31      6-Houston     Liberty                     32,223
# 32      1-Lubbock     Lubbock                    127,879
# 33       7-Austin    McLennan                     94,725
# 34      9-Midland     Midland                     69,398
# 35      6-Houston  Montgomery                    249,534
# 36    11-Edinburg      Nueces                    131,989
# 37     5-Beaumont      Orange                     33,580
# 38    3-Arlington      Parker                     55,761
# 39      1-Lubbock      Potter                     42,366
# 40      1-Lubbock     Randall                     55,187
# 41    3-Arlington    Rockwall                     41,956
# 43        4-Tyler       Smith                     80,889
# 44    11-Edinburg       Starr                     19,082
# 45    3-Arlington     Tarrant                    787,083
# 46      2-Abilene      Taylor                     53,907
# 48       7-Austin      Travis                    586,136
# 49  8-San Antonio    Victoria                     34,188
# 50      6-Houston      Walker                     26,918
# 51    11-Edinburg        Webb                     82,519
# 52      2-Abilene     Wichita                     50,211
# 53       7-Austin  Williamson                    258,095
# 54    3-Arlington        Wise                     25,430
#
#    Median income (dollars)  Abandonment  Emotional Abuse  Medical Neglect  \
# 0                   58,180          3.0             32.0             63.0
# 1                   72,663          1.0             45.0             46.0
# 2                   62,137         24.0            154.0            292.0
# 3                   65,854         43.0            832.0           1224.0
# 4                   49,771          5.0             34.0             63.0
# 5                   86,083          4.0             92.0            179.0
# 6                   60,393          5.0             58.0             70.0
# 7                   50,649          7.0            176.0            307.0
# 8                  113,305          7.0            309.0            381.0
# 43                  1614.0           597.0             192.0
# 44                   342.0           102.0              22.0
# 45                 14841.0          5204.0            1513.0
# 46                  2019.0           642.0             237.0
# 48                  6054.0          1895.0             499.0
# 49                   816.0           236.0             100.0
# 50                   302.0           135.0              65.0
# 51                  1520.0           509.0             191.0
# 52                  1488.0           473.0             191.0
# 53                  2745.0           947.0             265.0
# 54                   477.0           147.0              88.0
#
#     Refusal To Accept Parental Responsibility  Sex Trafficking  Sexual Abuse
# 0                                         5.0              2.0         255.0
# 1                                         8.0              3.0         250.0
# 2                                        67.0             12.0         852.0
# 3                                       186.0             59.0        4594.0
# 4                                        10.0              3.0         240.0
# 5                                        16.0              7.0         636.0
# 6                                        17.0              7.0         349.0
# 7                                        21.0              6.0         971.0
# 8                                        46.0              9.0        1160.0
# 9                                        10.0              4.0         314.0
# 10                                       13.0              3.0         242.0
# 11                                      217.0             55.0        4417.0
# 12                                       42.0             10.0        1236.0
# 13                                        8.0              8.0         469.0
# 14                                       26.0              7.0         381.0
# 17                                       15.0             10.0         687.0
# 18                                       10.0              6.0         420.0
# 19                                       16.0              4.0         287.0
# 20                                       19.0              4.0         403.0
# 21                                      552.0            119.0        9132.0
# 22                                        3.0              1.0         155.0
# 23                                       14.0              2.0         369.0
# 24                                        4.0              2.0         255.0
# 25                                       59.0             19.0        2178.0
# 26                                        8.0              2.0         172.0
# 27                                        9.0              2.0         302.0
# 28                                       23.0             11.0         387.0
# 29                                       14.0              4.0         430.0
# 30                                       13.0              1.0         334.0
# 31                                        6.0              3.0         302.0
# 32                                       23.0              3.0         850.0
# 33                                       29.0             11.0         688.0
# 34                                        8.0              5.0         382.0
# 35                                       44.0             22.0        1458.0
# 36                                       41.0             12.0         843.0
# 37                                        5.0              4.0         244.0
# 38                                       12.0              4.0         357.0
# 39                                       23.0              5.0         514.0
# 40                                       13.0              4.0         377.0
# 41                                        5.0              2.0         186.0
# 43                                       23.0              5.0         535.0
# 44                                        1.0              3.0         169.0
# 45                                      164.0             44.0        4055.0
# 46                                       15.0              8.0         532.0
# 48                                       87.0             45.0        1530.0
# 49                                        1.0              1.0         248.0
# 50                                        4.0              2.0         147.0
# 51                                       16.0              4.0         664.0
# 52                                       18.0              7.0         486.0
# 53                                       33.0             10.0         860.0
# 54                                        6.0              6.0         191.0

# %%
# plt.scatter(df["Abandonment"], df["Median income (dollars)"])
# R_square = r2_score(df["Abandonment"], df["Median income (dollars)"])
# plt.show()

# Remove commas from numbers in Median income amounts (Ex. 5,000 ==> 5000)
income_type_df["Median income (dollars)"] = income_type_df["Median income (dollars)"].replace(",", "", regex = True)
# print(df["Median income (dollars)"] )

# Convert Median Income from string to float datatype
income_type_df.astype({"Median income (dollars)" : 'float'}).dtypes
#
# Out:
# C:\Users\mojo\AppData\Local\Temp\ipykernel_14232\3605944783.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_type_df["Median income (dollars)"] = income_type_df["Median income (dollars)"].replace(",", "", regex = True)
# Region                                        object
# County                                        object
# Total Number of Households                    object
# Median income (dollars)                      float64
# Abandonment                                  float64
# Emotional Abuse                              float64
# Medical Neglect                              float64
# Neglectful Supervision                       float64
# Physical Abuse                               float64
# Physical Neglect                             float64
# Refusal To Accept Parental Responsibility    float64
# Sex Trafficking                              float64
# Sexual Abuse                                 float64
# dtype: object

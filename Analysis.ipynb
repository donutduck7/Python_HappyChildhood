# %%
# Import dependencies
import pandas as pd
from pathlib import Path 
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# Establish data path & read in CSV
data_path = "Resources/full_clean_dataset.csv"
df = pd.read_csv(data_path) 

# df = df.rename(columns={'Total':'Total Number of Households'})
# df = df.drop(columns="Unnamed: 0")
df = df.dropna()

# Create new df with vaues needed to answer question, "Does household income affect type of cases?"
income_type_df = df[['Region','County', 'Total Number of Households', 'Median income (dollars)', 'Abandonment', 'Emotional Abuse',
                     'Medical Neglect', 'Neglectful Supervision', 'Physical Abuse', 'Physical Neglect',
                     'Refusal To Accept Parental Responsibility', 'Sex Trafficking', 'Sexual Abuse']]
# Check work
income_type_df.head()
# Out:
#           Region    County Total Number of Households Median income (dollars)  \
# 0     5-Beaumont  Angelina                     34,276                  58,180
# 1       7-Austin   Bastrop                     37,278                  72,663
# 2       7-Austin      Bell                    143,361                  62,137
# 3  8-San Antonio     Bexar                    754,632                  65,854
# 4        4-Tyler     Bowie                     35,469                  49,771
#
#    Abandonment  Emotional Abuse  Medical Neglect  Neglectful Supervision  \
# 0          3.0             32.0             63.0                   684.0
# 1          1.0             45.0             46.0                   690.0
# 2         24.0            154.0            292.0                  3655.0
# 3         43.0            832.0           1224.0                 15509.0
# 4          5.0             34.0             63.0                   722.0
#
#    Physical Abuse  Physical Neglect  \
# 0           226.0             113.0
# 1           254.0              77.0
# 2          1219.0             455.0
# 3          5221.0            1766.0
# 4           248.0             167.0
#
#    Refusal To Accept Parental Responsibility  Sex Trafficking  Sexual Abuse
# 0                                        5.0              2.0         255.0
# 1                                        8.0              3.0         250.0
# 2                                       67.0             12.0         852.0
# 3                                      186.0             59.0        4594.0
# 4                                       10.0              3.0         240.0

# %%
# Remove commas from numbers (Ex. 5,000 ==> 5000)
income_type_df["Median income (dollars)"] = income_type_df["Median income (dollars)"].replace(",", "", regex = True)
income_type_df["Total Number of Households"] = income_type_df["Total Number of Households"].replace(",", "", regex = True)
# print(df["Median income (dollars)"] )

# Convert from string to float datatype
income_type_df = income_type_df.astype({"Median income (dollars)" : 'float'})
income_type_df = income_type_df.astype({"Total Number of Households" : 'float'})

#Check work
income_type_df.dtypes
# Out:
# C:\Users\mojo\AppData\Local\Temp\ipykernel_3556\2129504751.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_type_df["Median income (dollars)"] = income_type_df["Median income (dollars)"].replace(",", "", regex = True)
# C:\Users\mojo\AppData\Local\Temp\ipykernel_3556\2129504751.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_type_df["Total Number of Households"] = income_type_df["Total Number of Households"].replace(",", "", regex = True)
# Region                                        object
# County                                        object
# Total Number of Households                   float64
# Median income (dollars)                      float64
# Abandonment                                  float64
# Emotional Abuse                              float64
# Medical Neglect                              float64
# Neglectful Supervision                       float64
# Physical Abuse                               float64
# Physical Neglect                             float64
# Refusal To Accept Parental Responsibility    float64
# Sex Trafficking                              float64
# Sexual Abuse                                 float64
# dtype: object

# %%
income_type_df = income_type_df.sort_values(by=['Median income (dollars)'])
income_type_df
# Out:
#            Region      County  Total Number of Households  \
# 44    11-Edinburg       Starr                     19082.0
# 25    11-Edinburg     Hidalgo                    270891.0
# 4         4-Tyler       Bowie                     35469.0
# 7     11-Edinburg     Cameron                    137982.0
# 39      1-Lubbock      Potter                     42366.0
# 50      6-Houston      Walker                     26918.0
# 28     5-Beaumont   Jefferson                     96171.0
# 52      2-Abilene     Wichita                     50211.0
# 0      5-Beaumont    Angelina                     34276.0
# 32      1-Lubbock     Lubbock                    127879.0
# 51    11-Edinburg        Webb                     82519.0
# 36    11-Edinburg      Nueces                    131989.0
# 6        7-Austin      Brazos                     93580.0
# 19        4-Tyler       Gregg                     47877.0
# 31      6-Houston     Liberty                     32223.0
# 46      2-Abilene      Taylor                     53907.0
# 2        7-Austin        Bell                    143361.0
# 33       7-Austin    McLennan                     94725.0
# 37     5-Beaumont      Orange                     33580.0
# 24        4-Tyler   Henderson                     33671.0
# 10       7-Austin     Coryell                     27660.0
# 3   8-San Antonio       Bexar                    754632.0
# 18    3-Arlington     Grayson                     54309.0
# 13      9-Midland       Ector                     63738.0
# 43        4-Tyler       Smith                     80889.0
# 21      6-Houston      Harris                   1779980.0
# 22        4-Tyler    Harrison                     26795.0
# 27    3-Arlington        Hunt                     38072.0
# 26    3-Arlington        Hood                     25700.0
# 11    3-Arlington      Dallas                    992995.0
# 49  8-San Antonio    Victoria                     34188.0
# 1        7-Austin     Bastrop                     37278.0
# 17      6-Houston   Galveston                    143725.0
# 45    3-Arlington     Tarrant                    787083.0
# 29    3-Arlington     Johnson                     66686.0
# 34      9-Midland     Midland                     69398.0
# 40      1-Lubbock     Randall                     55187.0
# 54    3-Arlington        Wise                     25430.0
# 5       6-Houston    Brazoria                    133871.0
# 20  8-San Antonio   Guadalupe                     66711.0
# 23       7-Austin        Hays                    101449.0
# 14    3-Arlington       Ellis                     73227.0
# 9   8-San Antonio       Comal                     70544.0
# 30    3-Arlington     Kaufman                     50855.0
# 35      6-Houston  Montgomery                    249534.0
# 48       7-Austin      Travis                    586136.0
# 38    3-Arlington      Parker                     55761.0
# 53       7-Austin  Williamson                    258095.0
# 12    3-Arlington      Denton                    361770.0
# 8     3-Arlington      Collin                    414601.0
# 41    3-Arlington    Rockwall                     41956.0
#
#     Median income (dollars)  Abandonment  Emotional Abuse  Medical Neglect  \
# 44                  33871.0          1.0             12.0             32.0
# 25                  49142.0         19.0            254.0            476.0
# 4                   49771.0          5.0             34.0             63.0
# 7                   50649.0          7.0            176.0            307.0
# 39                  50661.0          6.0             62.0            132.0
# 50                  51528.0          1.0             20.0             29.0
# 28                  54797.0          1.0             84.0            123.0
# 52                  56944.0          5.0             72.0             98.0
# 0                   58180.0          3.0             32.0             63.0
# 32                  59161.0          1.0            141.0            201.0
# 51                  59603.0          2.0             53.0            140.0
# 36                  60361.0          9.0            140.0            225.0
# 6                   60393.0          5.0             58.0             70.0
# 19                  61496.0          4.0             76.0             54.0
# 31                  61525.0          5.0             37.0             69.0
# 46                  62107.0          4.0             69.0            121.0
# 2                   62137.0         24.0            154.0            292.0
# 33                  64320.0          5.0             91.0            170.0
# 30                  1048.0           373.0             119.0
# 35                  3590.0          1399.0             485.0
# 48                  6054.0          1895.0             499.0
# 38                  1041.0           358.0             141.0
# 53                  2745.0           947.0             265.0
# 12                  3824.0          1460.0             363.0
# 8                   3474.0          1337.0             323.0
# 41                   515.0           206.0              40.0
#
#     Refusal To Accept Parental Responsibility  Sex Trafficking  Sexual Abuse
# 44                                        1.0              3.0         169.0
# 25                                       59.0             19.0        2178.0
# 4                                        10.0              3.0         240.0
# 7                                        21.0              6.0         971.0
# 39                                       23.0              5.0         514.0
# 50                                        4.0              2.0         147.0
# 28                                       23.0             11.0         387.0
# 52                                       18.0              7.0         486.0
# 0                                         5.0              2.0         255.0
# 32                                       23.0              3.0         850.0
# 51                                       16.0              4.0         664.0
# 36                                       41.0             12.0         843.0
# 6                                        17.0              7.0         349.0
# 19                                       16.0              4.0         287.0
# 31                                        6.0              3.0         302.0
# 46                                       15.0              8.0         532.0
# 2                                        67.0             12.0         852.0
# 33                                       29.0             11.0         688.0
# 37                                        5.0              4.0         244.0
# 24                                        4.0              2.0         255.0
# 10                                       13.0              3.0         242.0
# 3                                       186.0             59.0        4594.0
# 18                                       10.0              6.0         420.0
# 13                                        8.0              8.0         469.0
# 43                                       23.0              5.0         535.0
# 21                                      552.0            119.0        9132.0
# 22                                        3.0              1.0         155.0
# 27                                        9.0              2.0         302.0
# 26                                        8.0              2.0         172.0
# 11                                      217.0             55.0        4417.0
# 49                                        1.0              1.0         248.0
# 1                                         8.0              3.0         250.0
# 17                                       15.0             10.0         687.0
# 45                                      164.0             44.0        4055.0
# 29                                       14.0              4.0         430.0
# 34                                        8.0              5.0         382.0
# 40                                       13.0              4.0         377.0
# 54                                        6.0              6.0         191.0
# 5                                        16.0              7.0         636.0
# 20                                       19.0              4.0         403.0
# 23                                       14.0              2.0         369.0
# 14                                       26.0              7.0         381.0
# 9                                        10.0              4.0         314.0
# 30                                       13.0              1.0         334.0
# 35                                       44.0             22.0        1458.0
# 48                                       87.0             45.0        1530.0
# 38                                       12.0              4.0         357.0
# 53                                       33.0             10.0         860.0
# 12                                       42.0             10.0        1236.0
# 8                                        46.0              9.0        1160.0
# 41                                        5.0              2.0         186.0

# %%
# Find correlation coefficient
income = income_type_df["Median income (dollars)"]

allegation_type = income_type_df["Abandonment"]
correlation = st.pearsonr(income, allegation_type)
print(f"The correlation with Abandonment is: {round(correlation[0],3)}")

allegation_type = income_type_df["Emotional Abuse"]
correlation = st.pearsonr(income, allegation_type)
print(f"The correlation with Emotional Abuse is: {round(correlation[0],2)}")

allegation_type = income_type_df["Medical Neglect"]
correlation = st.pearsonr(income, allegation_type)
print(f"The correlation with Medical Neglect is: {round(correlation[0],2)}")

allegation_type = income_type_df["Neglectful Supervision"]
correlation = st.pearsonr(income, allegation_type)
print(f"The correlation with Neglectful Supervision is: {round(correlation[0],2)}")

allegation_type = income_type_df["Physical Abuse"]
correlation = st.pearsonr(income, allegation_type)
print(f"The correlation with Physical Abuse is: {round(correlation[0],2)}")

allegation_type = income_type_df["Physical Abuse"]
correlation = st.pearsonr(income, allegation_type)
print(f"The correlation with Physical Abuse is: {round(correlation[0],2)}")

allegation_type = income_type_df["Physical Neglect"]
correlation = st.pearsonr(income, allegation_type)
print(f"The correlation with Physical Neglect is: {round(correlation[0],2)}")

allegation_type = income_type_df["Refusal To Accept Parental Responsibility"]
correlation = st.pearsonr(income, allegation_type)
print(f"The correlation with Refusal To Accept Parental Responsibility  is: {round(correlation[0],3)}")

allegation_type = income_type_df["Sex Trafficking"]
correlation = st.pearsonr(income, allegation_type)
print(f"The correlation with Sex Trafficking is: {round(correlation[0],2)}")

allegation_type = income_type_df["Sexual Abuse"]
correlation = st.pearsonr(income, allegation_type)
print(f"The correlation with Sexual Abuse is: {round(correlation[0],3)}")
# Out:
# The correlation with Abandonment is: 0.001
# The correlation with Emotional Abuse is: 0.07
# The correlation with Medical Neglect is: 0.03
# The correlation with Neglectful Supervision is: 0.01
# The correlation with Physical Abuse is: 0.02
# The correlation with Physical Abuse is: 0.02
# The correlation with Physical Neglect is: -0.04
# The correlation with Refusal To Accept Parental Responsibility  is: 0.005
# The correlation with Sex Trafficking is: 0.02
# The correlation with Sexual Abuse is: 0.002

# %%
# loop through columns containing types of allegations
# for x in income_type_df.columns[5:]:
    # get individual column header
#     allegation_name = income_type_df[x].head()
#     print(allegation_name)
    # get individual column contents
#     allegation_type = income_type_df[x]
#     print(allegation_type)
    # get & show correlation
#     correlation = st.pearsonr(income, allegation_type)
#     print(f'The correlation with {allegation_name} is: {round(correlation[0],2)}')
    
    # iterate counter
#     x = x+1

# %%
plt.scatter(income_type_df["Median income (dollars)"], 
            income_type_df["Emotional Abuse"], 
            color = "skyblue",
            edgecolors = "lightblue")
plt.xlabel('Median Household Income (USD)') 
plt.ylabel('Emotional Abuse Allegations')
plt.title('Emotional Abuse Allegations vs. Income \n Counties in Texas 2022')
#plt.xlim(30000, 130000)
plt.xticks(rotation=30)
plt.savefig("Images/emotional_abuse_vs_income")
plt.show()

# %%
plt.scatter(income_type_df["Median income (dollars)"], income_type_df["Abandonment"], 
            color = "wheat",
            marker = "h",
            edgecolors = "burlywood")
plt.xlabel('Median Household Income (USD)') 
plt.ylabel('Abandonment Allegations')
plt.title('Abandonment Allegations vs. Income \n Counties in Texas 2022')
plt.xticks(rotation=25)
plt.savefig("Images/abandonment_vs_income")
plt.show()

# %%
fix, ax = plt.subplots()
ax.scatter(income_type_df["Median income (dollars)"], 
           income_type_df["Abandonment"], 
           color = "skyblue",
           edgecolors = "lightblue",
           s = 50,
           marker = "h",
           label = "Abandonment")
ax.scatter(income_type_df["Median income (dollars)"], 
            income_type_df["Emotional Abuse"], 
            color = "wheat",
            edgecolors = "burlywood",
            s = 25,
            label = "Emotional Abuse")
ax.legend(loc='upper right')
plt.xlabel('Median Household Income (USD)') 
plt.ylabel('Allegations')
plt.title('Allegations vs. Income \n Counties in Texas 2022')
plt.xticks(rotation=25)
plt.savefig("Images/2_allegations_vs_income")
plt.show()
